# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from decimal import Decimal
from pyspark.sql.functions import *
import pyspark.sql.functions as F
import pandas as pd
import os
import re
import sys
import numpy as np

# %%
appName = "DataPrep"
master = "spark://LAPTOP-NKV0VISO.localdomain:7077"
# master = "local[*]"

# %%
# Create Spark session
spark = SparkSession.builder \
    .config('spark.ui.port','8080') \
    .appName(appName) \
    .master(master) \
    .getOrCreate()

# %%
alldata = spark.read.format("csv")\
                    .option("header", True)\
                    .option("delimiter",";") \
                    .load("hdfs://localhost:9000/data_upload/master/JD+Shopee+Lazada.csv")

# %%
df = alldata.toPandas()

# %%
from pythainlp.corpus.common import thai_words
from pythainlp import word_tokenize, Tokenizer

# %%
for index, row in df.iterrows():
    row['thToken'] = word_tokenize(row['Category'])

# %%
token =[]
for index, row in df.iterrows():
    token.append(row['thToken'])

# %%
df_copy = df

# %%
for index, row in df_copy.iterrows():
    x = re.findall('^Lazada', str(row["Platform"]))
    if x:
        row["Platform"]="Lazada"

# %%
for index, row in df_copy.iterrows():
    x = re.findall('^"Lazada', str(row["Platform"]))
    if x:
        row["Platform"]="Lazada"

# %%
df_copy.Platform.drop_duplicates()
# Out:
# 0                                                     None
# 1        https://www.lazada.co.th/products/fuji-fujifil...
# 2                                                   Shopee
# 1299                                        กล้องอินสแตนท์
# 1300                                             JDCentral
# 42229                                               Lazada
# 48978    https://www.lazada.co.th/products/junanvision-...
# 50357                                          กล้องคอมแพค
# 98434    https://www.lazada.co.th/products/0-acer-noteb...
# Name: Platform, dtype: object

# %%
df.Platform.drop_duplicates()
# Out:
# 0                                                     None
# 1        https://www.lazada.co.th/products/fuji-fujifil...
# 2                                                   Shopee
# 1299                                        กล้องอินสแตนท์
# 1300                                             JDCentral
# 42229                                               Lazada
# 48978    https://www.lazada.co.th/products/junanvision-...
# 50357                                          กล้องคอมแพค
# 98434    https://www.lazada.co.th/products/0-acer-noteb...
# Name: Platform, dtype: object

# %%
df_copy_copy = df_copy[df_copy.Platform.isin(['Shopee','Lazada','JDCentral'])]

# %%
df_copy_copy
# Out:
#                                                     Name     Price Review  \
# 2         !!!Promotion!!! ข้าวกล้องทองกข 43 ซื้อ 2 แถม 1     270.0     26
# 3      !!จัดส่งทันที ไส้กรองเครื่องฟอก Amway รุ่น1 (E...    1190.0     94
# 4              #CLLBSA4โค้ดส่วนลดoker xbox u 306 usb 2.0     315.0    125
# 5      #Shopdodi เคส Huawei Watch GT / GT2 46 mm Case...      75.0    173
# 6      ( Blesiya2 ) Pcie 1 To 4 Pci Express อะแดปเตอร...     561.0    107
# ...                                                  ...       ...    ...
# 98429  【ZLRC SG907 Pro】มีกระเป๋า กล้องชัด 4K กิมบอล 2...   3299.00     12
# 98430  【ZLRC SG908 Beast 2021】 กล้อง 4k with 3-Axis G...   4399.00     55
# 98431  【ZLRC SG908】Beast 2021 กล้อง 4k with 3-Axis Gi...   4188.00      5
# 98432  ❒✲♂  ชุดสายชาร์จกล้อง แท้ ZR50 ZR3500 ZR3600 (...    408.00      0
# 98433  ZSCMALL [รับประกัน3ปี] มาใหม่ล่าสุดR3 2200Uคอม...  13930.00     20
#
#                    Score                                              Image  \
# 2      4.857142857142857  https://cf.shopee.co.th/file/3697180ef1a3cfddf...
# 3      4.833333333333333  https://cf.shopee.co.th/file/abd6be605ca1c0d2f...
# 4      4.818181818181818  https://cf.shopee.co.th/file/3e5f2e0ed6e72b6ed...
# 5      4.840909090909091  https://cf.shopee.co.th/file/1d30876383fd21a54...
# 6      4.877005347593583  https://cf.shopee.co.th/file/79c891964fbdc54a1...
# ...                  ...                                                ...
# 98429                  0  https://th-live-05.slatic.net/p/84d9ef96bb1378...
# 98430                  0  https://th-live-05.slatic.net/p/348df1b6dd48fe...
# 98431                  0  https://th-live-05.slatic.net/p/ff0ec709b81c63...
# 98432                  0  https://th-live-05.slatic.net/p/7a77f1afd14880...
# 98433                  0  https://my-live-05.slatic.net/p/9c53c53c310995...
#
#                      Category  \
# 2                       ฟิล์ม
# 3             เครื่องฟอกอากาศ
# 4        อุปกรณ์สำหรับเล่นเกม
# 5           อุปกรณ์ไอทีสวมใส่
# 6      คอมพิวเตอร์และแล็ปท็อป
# ...                       ...
# 98429                    โดรน
# 98430                    โดรน
# 98431                    โดรน
# 98432              กล้อง DSLR
# 98433                แล็ปท็อป
#
#                                                      URL Platform Store  \
# 2      https://shopee.co.th/!!!Promotion!!!-ข้าวกล้อง...   Shopee  None
# 3      https://shopee.co.th/!!จัดส่งทันที-ไส้กรองเครื...   Shopee  None
# 4      https://shopee.co.th/#CLLBSA4โค้ดส่วนลดoker-xb...   Shopee  None
# 5      https://shopee.co.th/#Shopdodi-เคส-Huawei-Watc...   Shopee  None
# 6      https://shopee.co.th/(-Blesiya2-)-Pcie-1-To-4-...   Shopee  None
# ...                                                  ...      ...   ...
# 98429  https://www.lazada.co.th/products/zlrc-sg907-p...   Lazada  None
# 98430  https://www.lazada.co.th/products/zlrc-sg908-b...   Lazada  None
# 98431  https://www.lazada.co.th/products/zlrc-sg908be...   Lazada  None
# 98432  https://www.lazada.co.th/products/zr50-zr3500-...   Lazada  None
# 98433  https://www.lazada.co.th/products/zscmall-3-r3...   Lazada  None
#
#       Subcategory                  brand historical_sold view_count  \
# 2            None  No Brand(ไม่มียี่ห้อ)              92         36
# 3            None         Amway(แอมเวย์)             286         74
# 4            None        Oker(โอ๊คเคอร์)             579         61
# 5            None  No Brand(ไม่มียี่ห้อ)             902        512
# 6            None                   None            1145        322
# ...           ...                    ...             ...        ...
# 98429        None                   None            None       None
# 98430        None                   None            None       None
# 98431        None                   None            None       None
# 98432        None                   None            None       None
# 98433        None                   None            None       None
#
#               shop_location                       thToken
# 2      จังหวัดกรุงเทพมหานคร                       [ฟิล์ม]
# 3             จังหวัดนครปฐม             [เครื่องฟอกอากาศ]
# 4      จังหวัดกรุงเทพมหานคร  [อุปกรณ์, สำหรับ, เล่น, เกม]
# 5           จังหวัดปทุมธานี       [อุปกรณ์, ไอที, สวมใส่]
# 6                ต่างประเทศ  [คอมพิวเตอร์, และ, แล็ปท็อป]
# ...                     ...                           ...
# 98429                  None                        [โดรน]
# 98430                  None                        [โดรน]
# 98431                  None                        [โดรน]
# 98432                  None              [กล้อง,  , DSLR]
# 98433                  None                    [แล็ปท็อป]
#
# [98429 rows x 15 columns]

# %%
df_copy_copy.Category.drop_duplicates()
# Out:
# 2                                   ฟิล์ม
# 3                         เครื่องฟอกอากาศ
# 4                    อุปกรณ์สำหรับเล่นเกม
# 5                       อุปกรณ์ไอทีสวมใส่
# 6                  คอมพิวเตอร์และแล็ปท็อป
# 7                               ซอฟต์แวร์
# 8                                   อื่นๆ
# 9                            กล้องวงจรปิด
# 12                     อุปกรณ์เสริมมือถือ
# 15                  มือถือและอุปกรณ์เสริม
# 17           เครื่องซักผ้าและเครื่องอบผ้า
# 19                       เครื่องทำน้ำอุ่น
# 20                                  กล้อง
# 21                                ตู้เย็น
# 22                      อุปกรณ์เน็ตเวิร์ค
# 23                       ไมโครเวฟและเตาอบ
# 24                 แล็ปท็อปและคอมตั้งโต๊ะ
# 25                                เตาแก๊ส
# 27               เครื่องใช้ไฟฟ้าภายในบ้าน
# 29                               แท็บเล็ต
# 30                      อุปกรณ์เสริมกล้อง
# 31                    ชิ้นส่วนคอมพิวเตอร์
# 42              ปริ้นเตอร์และอุปกรณ์เสริม
# 43                อุปกรณ์เสริมคอมพิวเตอร์
# 48                                  เลนส์
# 51                 กล้องและอุปกรณ์ถ่ายภาพ
# 54                          เมมโมรี่การ์ด
# 55                                  พัดลม
# 57                   อุปกรณ์จัดเก็บข้อมูล
# 65                            พัดลมไอเย็น
# 68                         โทรศัพท์มือถือ
# 94                         แบตเตอรี่สำรอง
# 105                          โทรศัพท์บ้าน
# 120      เครื่องดูดฝุ่นและอุปกรณ์ดูแลพื้น
# 147         เครื่องใช้ไฟฟ้าในครัวขนาดเล็ก
# 153                   อุปกรณ์กันรอยหน้าจอ
# 158                       เคสและซองมือถือ
# 171                          กล้องแอคชั่น
# 289                      เครื่องปรับอากาศ
# 442               เตารีดและอุปกรณ์ดูแลผ้า
# 1300      อุปกรณ์อิเล็กทรอนิกส์และแกดเจ็ต
# 1301               คอมพิวเตอร์และสำนักงาน
# 1312            โทรศัพท์มือถือและแท็บเล็ต
# 42229                                โดรน
# 42230        กล้องและระบบรักษาความปลอดภัย
# 42231                            แล็ปท็อป
# 42232                    กล้องมิลเลอร์เลส
# 42233                         กล้องวิดีโอ
# 42236                      กล้องอินสแตนท์
# 42238              คอมพิวเตอร์แบบตั้งโต๊ะ
# 42242                         กล้องคอมแพค
# 42247                          กล้อง DSLR
# 42576                เครื่องเล่นเกมคอมโซล
# Name: Category, dtype: object

# %%
drop=[]
df_copy_copy4 =df_copy_copy[df_copy_copy.Category.isin(['เครื่องทำน้ำอุ่น','อื่นๆ','ไมโครเวฟและเตาอบ','เตาแก๊ส','เครื่องใช้ไฟฟ้าภายในบ้าน','พัดลม','พัดลมไอเย็น','เครื่องดูดฝุ่นและอุปกรณ์ดูแลพื้น','เครื่องใช้ไฟฟ้าในครัวขนาดเล็ก','เครื่องปรับอากาศ','เตารีดและอุปกรณ์ดูแลผ้า','เครื่องซักผ้าและเครื่องอบผ้า','ตู้เย็น','พัดลม','พัดลม','พัดลม','เครื่องฟอกอากาศ'])]
for index, row in df_copy_copy4.iterrows():
        drop.append(index)

# %%
df_copy_copy = df_copy_copy.drop(drop)

# %%
df_copy_copy.Category.drop_duplicates()
# Out:
# 2                                  ฟิล์ม
# 4                   อุปกรณ์สำหรับเล่นเกม
# 5                      อุปกรณ์ไอทีสวมใส่
# 6                 คอมพิวเตอร์และแล็ปท็อป
# 7                              ซอฟต์แวร์
# 9                           กล้องวงจรปิด
# 12                    อุปกรณ์เสริมมือถือ
# 15                 มือถือและอุปกรณ์เสริม
# 20                                 กล้อง
# 22                     อุปกรณ์เน็ตเวิร์ค
# 24                แล็ปท็อปและคอมตั้งโต๊ะ
# 29                              แท็บเล็ต
# 30                     อุปกรณ์เสริมกล้อง
# 31                   ชิ้นส่วนคอมพิวเตอร์
# 42             ปริ้นเตอร์และอุปกรณ์เสริม
# 43               อุปกรณ์เสริมคอมพิวเตอร์
# 48                                 เลนส์
# 51                กล้องและอุปกรณ์ถ่ายภาพ
# 54                         เมมโมรี่การ์ด
# 57                  อุปกรณ์จัดเก็บข้อมูล
# 68                        โทรศัพท์มือถือ
# 94                        แบตเตอรี่สำรอง
# 105                         โทรศัพท์บ้าน
# 153                  อุปกรณ์กันรอยหน้าจอ
# 158                      เคสและซองมือถือ
# 171                         กล้องแอคชั่น
# 1300     อุปกรณ์อิเล็กทรอนิกส์และแกดเจ็ต
# 1301              คอมพิวเตอร์และสำนักงาน
# 1312           โทรศัพท์มือถือและแท็บเล็ต
# 42229                               โดรน
# 42230       กล้องและระบบรักษาความปลอดภัย
# 42231                           แล็ปท็อป
# 42232                   กล้องมิลเลอร์เลส
# 42233                        กล้องวิดีโอ
# 42236                     กล้องอินสแตนท์
# 42238             คอมพิวเตอร์แบบตั้งโต๊ะ
# 42242                        กล้องคอมแพค
# 42247                         กล้อง DSLR
# 42576               เครื่องเล่นเกมคอมโซล
# Name: Category, dtype: object

# %%
df_copy_copy_final = df_copy_copy

# %%
#df['Subcategory'] = df['Subcategory'].map({'เมาส์และคีย์บอร์ด':'อุปกรณ์เสริมคอมพิวเตอร์',
                             #'อุปกรณ์อิเล็กทรอนิกส์อัจฉริยะ':'อุปกรณ์เสริมคอมพิวเตอร์',
                             #'อุปกรณ์จัดเก็บและเคลื่อนย้ายข้อมูล':'อุปกรณ์จัดเก็บข้อมูล'})
df_copy_copy_final['Subcategory'] = df_copy_copy['Subcategory'].replace(
    ['เมาส์และคีย์บอร์ด','อุปกรณ์อิเล็กทรอนิกส์อัจฉริยะ','อุปกรณ์จัดเก็บและเคลื่อนย้ายข้อมูล'],
    ['อุปกรณ์เสริมคอมพิวเตอร์','อุปกรณ์เสริมคอมพิวเตอร์','อุปกรณ์จัดเก็บข้อมูล'])
#df.replace(to_replace ="อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม",value ="อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม")
#df.replace(to_replace ="เมาส์และคีย์บอร์ด",value ="ชิ้นส่วนคอมพิวเตอร์")
#df.replace(to_replace ="กล้อง",value ="กล้อง")
#df.replace(to_replace ="อุปกรณ์เสริมกล้อง",value ="อุปกรณ์เสริมกล้อง")
#df.replace(to_replace ="ชิ้นส่วนคอมพิวเตอร์",value ="ชิ้นส่วนคอมพิวเตอร์")
df_copy_copy_final = df_copy_copy[df_copy_copy.Subcategory != "อุปกรณ์อิเล็กทรอนิกส์ในรถยนต์"]
df_copy_copy_final = df_copy_copy[df_copy_copy.Subcategory != "เครื่องเสียงและสื่อบันเทิง"]

# %%
df_copy_copy_final1 = df_copy_copy_final[df_copy_copy_final.Platform.isin(['JDCentral'])]

# %%
df_copy_copy_final2 =  df_copy_copy_final[df_copy_copy_final.Platform.isin(['Shopee','Lazada'])]

# %%
mapping = {
        'ฟิล์ม':'อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต',
        'อุปกรณ์สำหรับเล่นเกม':'อุปกรณ์สำหรับเกมเมอร์',
        'อุปกรณ์ไอทีสวมใส่':'อุปกรณ์เสริมคอมพิวเตอร์',
        'ซอฟต์แวร์':'อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม',
        'กล้องวงจรปิด':'กล้อง',
        'อุปกรณ์เสริมมือถือ':'อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต',
        'มือถือและอุปกรณ์เสริม':'อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต',
        'กล้อง':'กล้อง',
        'อุปกรณ์เน็ตเวิร์ค':'อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม',
        'แล็ปท็อปและคอมตั้งโต๊ะ':'คอมพิวเตอร์และแล็ปท็อป',
        'แท็บเล็ต':'โทรศัพท์มือถือและแท็บเล็ต',
        'อุปกรณ์เสริมกล้อง':'อุปกรณ์เสริมกล้อง',
        'ชิ้นส่วนคอมพิวเตอร์':'ชิ้นส่วนคอมพิวเตอร์',
        'ปริ้นเตอร์และอุปกรณ์เสริม':'อุปกรณ์เสริมคอมพิวเตอร์',
        'อุปกรณ์เสริมคอมพิวเตอร์':'อุปกรณ์เสริมคอมพิวเตอร์',
        'เลนส์':'อุปกรณ์เสริมกล้อง',
        'กล้องและอุปกรณ์ถ่ายภาพ':'อุปกรณ์เสริมกล้อง',
        'เมมโมรี่การ์ด':'อุปกรณ์จัดเก็บข้อมูล',
        'อุปกรณ์จัดเก็บข้อมูล':'อุปกรณ์จัดเก็บข้อมูล',
        'โทรศัพท์มือถือ':'โทรศัพท์มือถือและแท็บเล็ต',
        'แบตเตอรี่สำรอง':'อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต',
        'โทรศัพท์บ้าน':'โทรศัพท์มือถือและแท็บเล็ต',
        'อุปกรณ์กันรอยหน้าจอ':'อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต',
        'เคสและซองมือถือ':'อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต',
        'กล้องแอคชั่น':'กล้อง',
        'โทรศัพท์มือถือและแท็บเล็ต':'โทรศัพท์มือถือและแท็บเล็ต',
        'โดรน':'กล้อง',
        'กล้องและระบบรักษาความปลอดภัย':'กล้อง',
        'แล็ปท็อป':'คอมพิวเตอร์และแล็ปท็อป',
        'กล้องมิลเลอร์เลส':'กล้อง',
        'กล้องวิดีโอ':'กล้อง',
        'กล้องอินสแตนท์':'กล้อง',
        'คอมพิวเตอร์แบบตั้งโต๊ะ':'คอมพิวเตอร์และแล็ปท็อป',
        'กล้องคอมแพค':'กล้อง',
        'กล้อง DSLR':'กล้อง',
        'เครื่องเล่นเกมคอมโซล':'อุปกรณ์สำหรับเกมเมอร์',
        'คอมพิวเตอร์และแล็ปท็อป':'คอมพิวเตอร์และแล็ปท็อป'
    }

# %%
df_copy_copy_final2['Subcategory'] = df_copy_copy_final2.Category.map(mapping)
# Out:
# <ipython-input-30-fc6fc36d70c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_copy_final2['Subcategory'] = df_copy_copy_final2.Category.map(mapping)

# %%
df_copy_copy.Subcategory.drop_duplicates()
# Out:
# 2                                         None
# 1300                เครื่องเสียงและสื่อบันเทิง
# 1301                   อุปกรณ์เสริมคอมพิวเตอร์
# 1305             อุปกรณ์อิเล็กทรอนิกส์ในรถยนต์
# 1312     อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต
# 1322                 โทรศัพท์มือถือและแท็บเล็ต
# 1326                     อุปกรณ์สำหรับเกมเมอร์
# 1329                                     กล้อง
# 1338                      อุปกรณ์จัดเก็บข้อมูล
# 1346                         อุปกรณ์เสริมกล้อง
# 1363                    คอมพิวเตอร์และแล็ปท็อป
# 1368                       ชิ้นส่วนคอมพิวเตอร์
# 1467    อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม
# Name: Subcategory, dtype: object

# %%
df_copy_copy_final2
# Out:
#                                                     Name     Price Review  \
# 2         !!!Promotion!!! ข้าวกล้องทองกข 43 ซื้อ 2 แถม 1     270.0     26
# 4              #CLLBSA4โค้ดส่วนลดoker xbox u 306 usb 2.0     315.0    125
# 5      #Shopdodi เคส Huawei Watch GT / GT2 46 mm Case...      75.0    173
# 6      ( Blesiya2 ) Pcie 1 To 4 Pci Express อะแดปเตอร...     561.0    107
# 7       (008) Arduino Nano V3.0 CH340 (ไม่มีเก็บปลายทาง)     120.0      6
# ...                                                  ...       ...    ...
# 98429  【ZLRC SG907 Pro】มีกระเป๋า กล้องชัด 4K กิมบอล 2...   3299.00     12
# 98430  【ZLRC SG908 Beast 2021】 กล้อง 4k with 3-Axis G...   4399.00     55
# 98431  【ZLRC SG908】Beast 2021 กล้อง 4k with 3-Axis Gi...   4188.00      5
# 98432  ❒✲♂  ชุดสายชาร์จกล้อง แท้ ZR50 ZR3500 ZR3600 (...    408.00      0
# 98433  ZSCMALL [รับประกัน3ปี] มาใหม่ล่าสุดR3 2200Uคอม...  13930.00     20
#
#                    Score                                              Image  \
# 2      4.857142857142857  https://cf.shopee.co.th/file/3697180ef1a3cfddf...
# 4      4.818181818181818  https://cf.shopee.co.th/file/3e5f2e0ed6e72b6ed...
# 5      4.840909090909091  https://cf.shopee.co.th/file/1d30876383fd21a54...
# 6      4.877005347593583  https://cf.shopee.co.th/file/79c891964fbdc54a1...
# 7                    5.0  https://cf.shopee.co.th/file/9633b0ce6f0ea3e6d...
# ...                  ...                                                ...
# 98429                  0  https://th-live-05.slatic.net/p/84d9ef96bb1378...
# 98430                  0  https://th-live-05.slatic.net/p/348df1b6dd48fe...
# 98431                  0  https://th-live-05.slatic.net/p/ff0ec709b81c63...
# 98432                  0  https://th-live-05.slatic.net/p/7a77f1afd14880...
# 98433                  0  https://my-live-05.slatic.net/p/9c53c53c310995...
#
#                      Category  \
# 2                       ฟิล์ม
# 4        อุปกรณ์สำหรับเล่นเกม
# 5           อุปกรณ์ไอทีสวมใส่
# 6      คอมพิวเตอร์และแล็ปท็อป
# 7                   ซอฟต์แวร์
# ...                       ...
# 98429                    โดรน
# 98430                    โดรน
# 98431                    โดรน
# 98432              กล้อง DSLR
# 98433                แล็ปท็อป
#
#                                                      URL Platform Store  \
# 2      https://shopee.co.th/!!!Promotion!!!-ข้าวกล้อง...   Shopee  None
# 4      https://shopee.co.th/#CLLBSA4โค้ดส่วนลดoker-xb...   Shopee  None
# 5      https://shopee.co.th/#Shopdodi-เคส-Huawei-Watc...   Shopee  None
# 6      https://shopee.co.th/(-Blesiya2-)-Pcie-1-To-4-...   Shopee  None
# 7      https://shopee.co.th/(008)-Arduino-Nano-V3.0-C...   Shopee  None
# ...                                                  ...      ...   ...
# 98429  https://www.lazada.co.th/products/zlrc-sg907-p...   Lazada  None
# 98430  https://www.lazada.co.th/products/zlrc-sg908-b...   Lazada  None
# 98431  https://www.lazada.co.th/products/zlrc-sg908be...   Lazada  None
# 98432  https://www.lazada.co.th/products/zr50-zr3500-...   Lazada  None
# 98433  https://www.lazada.co.th/products/zscmall-3-r3...   Lazada  None
#
#                                   Subcategory                  brand  \
# 2       อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต  No Brand(ไม่มียี่ห้อ)
# 4                       อุปกรณ์สำหรับเกมเมอร์        Oker(โอ๊คเคอร์)
# 5                     อุปกรณ์เสริมคอมพิวเตอร์  No Brand(ไม่มียี่ห้อ)
# 6                      คอมพิวเตอร์และแล็ปท็อป                   None
# 7      อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม                   None
# ...                                       ...                    ...
# 98429                                   กล้อง                   None
# 98430                                   กล้อง                   None
# 98431                                   กล้อง                   None
# 98432                                   กล้อง                   None
# 98433                  คอมพิวเตอร์และแล็ปท็อป                   None
#
#       historical_sold view_count         shop_location  \
# 2                  92         36  จังหวัดกรุงเทพมหานคร
# 4                 579         61  จังหวัดกรุงเทพมหานคร
# 5                 902        512       จังหวัดปทุมธานี
# 6                1145        322            ต่างประเทศ
# 7                  37         28          จังหวัดสงขลา
# ...               ...        ...                   ...
# 98429            None       None                  None
# 98430            None       None                  None
# 98431            None       None                  None
# 98432            None       None                  None
# 98433            None       None                  None
#
#                           Token
# 2                         ฟิล์ม
# 4       อุปกรณ์ สำหรับ เล่น เกม
# 5           อุปกรณ์ ไอที สวมใส่
# 6      คอมพิวเตอร์ และ แล็ปท็อป
# 7                     ซอฟต์แวร์
# ...                         ...
# 98429                      โดรน
# 98430                      โดรน
# 98431                      โดรน
# 98432              กล้อง   DSLR
# 98433                  แล็ปท็อป
#
# [15180 rows x 15 columns]

# %%
frames = [df_copy_copy_final1, df_copy_copy_final2]

# %%
result = pd.concat(frames)

# %%
result
# Out:
#                                                     Name     Price Review  \
# 1301   Becao เมาส์สำหรับเล่นเกม USB เมาส์คอมพิวเตอร์ ...     300.0      0
# 1303             Genius Media 100 Laser Pointer Wireless     990.0      0
# 1304                    SIGNO GM908 Optical Gaming mouse     299.0      0
# 1305               Transcend กล้องติดรถยนต์ DrivePro 110    3190.0      0
# 1306    เมาส์ไร้สาย LOGITECH WIRELESS OPTICAL MOUSE M185     429.0      0
# ...                                                  ...       ...    ...
# 98429  【ZLRC SG907 Pro】มีกระเป๋า กล้องชัด 4K กิมบอล 2...   3299.00     12
# 98430  【ZLRC SG908 Beast 2021】 กล้อง 4k with 3-Axis G...   4399.00     55
# 98431  【ZLRC SG908】Beast 2021 กล้อง 4k with 3-Axis Gi...   4188.00      5
# 98432  ❒✲♂  ชุดสายชาร์จกล้อง แท้ ZR50 ZR3500 ZR3600 (...    408.00      0
# 98433  ZSCMALL [รับประกัน3ปี] มาใหม่ล่าสุดR3 2200Uคอม...  13930.00     20
#
#       Score                                              Image  \
# 1301    0.0  https://img.jd.co.th/n1/jfs/t25/254/5221940100...
# 1303    0.0  https://img.jd.co.th/n1/jfs/t25/163/9628471997...
# 1304    0.0  https://img.jd.co.th/n1/jfs/t31/222/3802209400...
# 1305    0.0  https://img.jd.co.th/n1/jfs/t7/35/3603756691/9...
# 1306    0.0  https://img.jd.co.th/n1/jfs/t58/365/509988337/...
# ...     ...                                                ...
# 98429     0  https://th-live-05.slatic.net/p/84d9ef96bb1378...
# 98430     0  https://th-live-05.slatic.net/p/348df1b6dd48fe...
# 98431     0  https://th-live-05.slatic.net/p/ff0ec709b81c63...
# 98432     0  https://th-live-05.slatic.net/p/7a77f1afd14880...
# 98433     0  https://my-live-05.slatic.net/p/9c53c53c310995...
#
#                               Category  \
# 1301            คอมพิวเตอร์และสำนักงาน
# 1303            คอมพิวเตอร์และสำนักงาน
# 1304            คอมพิวเตอร์และสำนักงาน
# 1305   อุปกรณ์อิเล็กทรอนิกส์และแกดเจ็ต
# 1306            คอมพิวเตอร์และสำนักงาน
# ...                                ...
# 98429                             โดรน
# 98430                             โดรน
# 98431                             โดรน
# 98432                       กล้อง DSLR
# 98433                         แล็ปท็อป
#
#                                                      URL   Platform  \
# 1301    https://www.jd.co.th/product/A_P_J_10020238.html  JDCentral
# 1303    https://www.jd.co.th/product/A_P_J_10023366.html  JDCentral
# 1304    https://www.jd.co.th/product/A_P_J_10023383.html  JDCentral
# 1305    https://www.jd.co.th/product/A_P_J_10023400.html  JDCentral
# 1306    https://www.jd.co.th/product/A_P_J_10023410.html  JDCentral
# ...                                                  ...        ...
# 98429  https://www.lazada.co.th/products/zlrc-sg907-p...     Lazada
# 98430  https://www.lazada.co.th/products/zlrc-sg908-b...     Lazada
# 98431  https://www.lazada.co.th/products/zlrc-sg908be...     Lazada
# 98432  https://www.lazada.co.th/products/zr50-zr3500-...     Lazada
# 98433  https://www.lazada.co.th/products/zscmall-3-r3...     Lazada
#
#                     Store                    Subcategory brand  \
# 1301   Becao Global Store        อุปกรณ์เสริมคอมพิวเตอร์  None
# 1303            Wawa Easy        อุปกรณ์เสริมคอมพิวเตอร์  None
# 1304            Wawa Easy        อุปกรณ์เสริมคอมพิวเตอร์  None
# 1305            Wawa Easy  อุปกรณ์อิเล็กทรอนิกส์ในรถยนต์  None
# 1306            Wawa Easy        อุปกรณ์เสริมคอมพิวเตอร์  None
# ...                   ...                            ...   ...
# 98429                None                          กล้อง  None
# 98430                None                          กล้อง  None
# 98431                None                          กล้อง  None
# 98432                None                          กล้อง  None
# 98433                None         คอมพิวเตอร์และแล็ปท็อป  None
#
#       historical_sold view_count shop_location  \
# 1301             None       None          None
# 1303             None       None          None
# 1304             None       None          None
# 1305             None       None          None
# 1306             None       None          None
# ...               ...        ...           ...
# 98429            None       None          None
# 98430            None       None          None
# 98431            None       None          None
# 98432            None       None          None
# 98433            None       None          None
#
#                                     Token
# 1301             คอมพิวเตอร์ และ สำนักงาน
# 1303             คอมพิวเตอร์ และ สำนักงาน
# 1304             คอมพิวเตอร์ และ สำนักงาน
# 1305   อุปกรณ์ อิเล็กทรอนิกส์ และ แกดเจ็ต
# 1306             คอมพิวเตอร์ และ สำนักงาน
# ...                                   ...
# 98429                                โดรน
# 98430                                โดรน
# 98431                                โดรน
# 98432                        กล้อง   DSLR
# 98433                            แล็ปท็อป
#
# [90309 rows x 15 columns]

# %%
result = result.rename(columns={"Category": "Category1"})
result = result.rename(columns={"Subcategory": "Category"})
result = result.rename(columns={"Category1": "Subcategory"})

# %%
result
# Out:
#                                                     Name     Price Review  \
# 1301   Becao เมาส์สำหรับเล่นเกม USB เมาส์คอมพิวเตอร์ ...     300.0      0
# 1303             Genius Media 100 Laser Pointer Wireless     990.0      0
# 1304                    SIGNO GM908 Optical Gaming mouse     299.0      0
# 1305               Transcend กล้องติดรถยนต์ DrivePro 110    3190.0      0
# 1306    เมาส์ไร้สาย LOGITECH WIRELESS OPTICAL MOUSE M185     429.0      0
# ...                                                  ...       ...    ...
# 98429  【ZLRC SG907 Pro】มีกระเป๋า กล้องชัด 4K กิมบอล 2...   3299.00     12
# 98430  【ZLRC SG908 Beast 2021】 กล้อง 4k with 3-Axis G...   4399.00     55
# 98431  【ZLRC SG908】Beast 2021 กล้อง 4k with 3-Axis Gi...   4188.00      5
# 98432  ❒✲♂  ชุดสายชาร์จกล้อง แท้ ZR50 ZR3500 ZR3600 (...    408.00      0
# 98433  ZSCMALL [รับประกัน3ปี] มาใหม่ล่าสุดR3 2200Uคอม...  13930.00     20
#
#       Score                                              Image  \
# 1301    0.0  https://img.jd.co.th/n1/jfs/t25/254/5221940100...
# 1303    0.0  https://img.jd.co.th/n1/jfs/t25/163/9628471997...
# 1304    0.0  https://img.jd.co.th/n1/jfs/t31/222/3802209400...
# 1305    0.0  https://img.jd.co.th/n1/jfs/t7/35/3603756691/9...
# 1306    0.0  https://img.jd.co.th/n1/jfs/t58/365/509988337/...
# ...     ...                                                ...
# 98429     0  https://th-live-05.slatic.net/p/84d9ef96bb1378...
# 98430     0  https://th-live-05.slatic.net/p/348df1b6dd48fe...
# 98431     0  https://th-live-05.slatic.net/p/ff0ec709b81c63...
# 98432     0  https://th-live-05.slatic.net/p/7a77f1afd14880...
# 98433     0  https://my-live-05.slatic.net/p/9c53c53c310995...
#
#                            Subcategory  \
# 1301            คอมพิวเตอร์และสำนักงาน
# 1303            คอมพิวเตอร์และสำนักงาน
# 1304            คอมพิวเตอร์และสำนักงาน
# 1305   อุปกรณ์อิเล็กทรอนิกส์และแกดเจ็ต
# 1306            คอมพิวเตอร์และสำนักงาน
# ...                                ...
# 98429                             โดรน
# 98430                             โดรน
# 98431                             โดรน
# 98432                       กล้อง DSLR
# 98433                         แล็ปท็อป
#
#                                                      URL   Platform  \
# 1301    https://www.jd.co.th/product/A_P_J_10020238.html  JDCentral
# 1303    https://www.jd.co.th/product/A_P_J_10023366.html  JDCentral
# 1304    https://www.jd.co.th/product/A_P_J_10023383.html  JDCentral
# 1305    https://www.jd.co.th/product/A_P_J_10023400.html  JDCentral
# 1306    https://www.jd.co.th/product/A_P_J_10023410.html  JDCentral
# ...                                                  ...        ...
# 98429  https://www.lazada.co.th/products/zlrc-sg907-p...     Lazada
# 98430  https://www.lazada.co.th/products/zlrc-sg908-b...     Lazada
# 98431  https://www.lazada.co.th/products/zlrc-sg908be...     Lazada
# 98432  https://www.lazada.co.th/products/zr50-zr3500-...     Lazada
# 98433  https://www.lazada.co.th/products/zscmall-3-r3...     Lazada
#
#                     Store                       Category brand  \
# 1301   Becao Global Store        อุปกรณ์เสริมคอมพิวเตอร์  None
# 1303            Wawa Easy        อุปกรณ์เสริมคอมพิวเตอร์  None
# 1304            Wawa Easy        อุปกรณ์เสริมคอมพิวเตอร์  None
# 1305            Wawa Easy  อุปกรณ์อิเล็กทรอนิกส์ในรถยนต์  None
# 1306            Wawa Easy        อุปกรณ์เสริมคอมพิวเตอร์  None
# ...                   ...                            ...   ...
# 98429                None                          กล้อง  None
# 98430                None                          กล้อง  None
# 98431                None                          กล้อง  None
# 98432                None                          กล้อง  None
# 98433                None         คอมพิวเตอร์และแล็ปท็อป  None
#
#       historical_sold view_count shop_location  \
# 1301             None       None          None
# 1303             None       None          None
# 1304             None       None          None
# 1305             None       None          None
# 1306             None       None          None
# ...               ...        ...           ...
# 98429            None       None          None
# 98430            None       None          None
# 98431            None       None          None
# 98432            None       None          None
# 98433            None       None          None
#
#                                     Token
# 1301             คอมพิวเตอร์ และ สำนักงาน
# 1303             คอมพิวเตอร์ และ สำนักงาน
# 1304             คอมพิวเตอร์ และ สำนักงาน
# 1305   อุปกรณ์ อิเล็กทรอนิกส์ และ แกดเจ็ต
# 1306             คอมพิวเตอร์ และ สำนักงาน
# ...                                   ...
# 98429                                โดรน
# 98430                                โดรน
# 98431                                โดรน
# 98432                        กล้อง   DSLR
# 98433                            แล็ปท็อป
#
# [90309 rows x 15 columns]

# %%
Mobile_phones_and_tablets =  result[result.Category.isin(['โทรศัพท์มือถือและแท็บเล็ต'])]
Mobile_phone_and_tablet_accessories =  result[result.Category.isin(['อุปกรณ์เสริมโทรศัพท์มือถือและแท็บเล็ต'])]
Computers_and_laptops =  result[result.Category.isin(['คอมพิวเตอร์และแล็ปท็อป'])]
Storage_device =  result[result.Category.isin(['อุปกรณ์จัดเก็บข้อมูล'])]
Internet_connection_devices_and_programs =  result[result.Category.isin(['อุปกรณ์เชื่อมต่ออินเทอร์เน็ตและโปรแกรม'])]
Computer_accessories =  result[result.Category.isin(['อุปกรณ์เสริมคอมพิวเตอร์'])]
Computer_Parts =  result[result.Category.isin(['ชิ้นส่วนคอมพิวเตอร์'])]
Camera =  result[result.Category.isin(['กล้อง'])]
Camera_accessories =  result[result.Category.isin(['อุปกรณ์เสริมกล้อง'])]
Gamer_gear =  result[result.Category.isin(['อุปกรณ์สำหรับเกมเมอร์'])]

# %%
# Mobile_phones_and_tablets.to_csv('./result/Mobile_phones_and_tablets.csv',encoding='utf-8-sig',sep=';',index= False)
# Mobile_phone_and_tablet_accessories.to_csv('./result/Mobile_phone_and_tablet_accessories.csv',encoding='utf-8-sig',sep=';',index= False)
# Computers_and_laptops.to_csv('./result/Computers_and_laptops.csv',encoding='utf-8-sig',sep=';',index= False)
# Storage_device.to_csv('./result/Storage_device.csv',encoding='utf-8-sig',sep=';',index= False)
# Internet_connection_devices_and_programs.to_csv('./result/Internet_connection_devices_and_programs.csv',encoding='utf-8-sig',sep=';',index= False)
# Computer_accessories.to_csv('./result/Computer_accessories.csv',encoding='utf-8-sig',sep=';',index= False)
# Computer_Parts.to_csv('./result/Computer_Parts.csv',encoding='utf-8-sig',sep=';',index= False)
# Camera.to_csv('./result/Camera.csv',encoding='utf-8-sig',sep=';',index= False)
# Camera_accessories.to_csv('./result/Camera_accessories.csv',encoding='utf-8-sig',sep=';',index= False)
# Gamer_gear.to_csv('./result/Gamer_gear.csv',encoding='utf-8-sig',sep=';',index= False)

# %%
result.to_csv('./result/result.csv',encoding='utf-8-sig',sep=';',index= False)

# %%
# result.to_csv('./result/result2.csv',encoding='utf-8-sig')

# %% [markdown]
# df_copy_copy.Category.drop_duplicates().to_csv('Subcate.csv',encoding='utf-8-sig',sep=';',index= False)

# %% [markdown]
# df_copy_copy.Category.drop_duplicates().to_csv('Subcate.csv',encoding='utf-8-sig')
